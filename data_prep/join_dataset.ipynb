# %%
import pandas as pd
import re
import json
import ast
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from Levenshtein import distance as lev
import time

# %%
food_path = "../data/dev_set.json"
flavor_path = "../data/flavor_DB.json"

# %%
def flatten(path, cols, meta):
   # load data using Python JSON module
    with open(path,'r') as f:
        data = json.loads(f.read())
        
    # Flatten data
    df = pd.json_normalize(
        data, 
        record_path =cols, 
        meta=meta
    )
    return df

# %%
food_df = pd.read_json(food_path)
food_df.info()
food_df.iloc[0:5, :]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fsa_lights_per100g   1000 non-null   object
#  1   id                   1000 non-null   object
#  2   ingredients          1000 non-null   object
#  3   instructions         1000 non-null   object
#  4   nutr_per_ingredient  1000 non-null   object
#  5   nutr_values_per100g  1000 non-null   object
#  6   partition            1000 non-null   object
#  7   quantity             1000 non-null   object
#  8   title                1000 non-null   object
#  9   unit                 1000 non-null   object
#  10  url                  1000 non-null   object
#  11  weight_per_ingr      1000 non-null   object
# dtypes: object(12)
# memory usage: 93.9+ KB
#                                   fsa_lights_per100g          id  \
# 0  {'fat': 'red', 'salt': 'green', 'saturates': '...  fb51dbcb2f
# 1  {'fat': 'red', 'salt': 'orange', 'saturates': ...  46dbd27b9a
# 2  {'fat': 'red', 'salt': 'orange', 'saturates': ...  dce5271a52
# 3  {'fat': 'red', 'salt': 'green', 'saturates': '...  8f873f5a14
# 4  {'fat': 'orange', 'salt': 'red', 'saturates': ...  b9b89434c6
#
#                                          ingredients  \
# 0  [{'text': 'butter, without salt'}, {'text': 's...
# 1  [{'text': 'spices, poppy seed'}, {'text': 'vin...
# 2  [{'text': 'apples, raw, with skin'}, {'text': ...
# 3  [{'text': 'butter, without salt'}, {'text': 'w...
# 4  [{'text': 'beans, snap, green, raw'}, {'text':...
#
#                                         instructions  \
# 0  [{'text': 'Finely chop the dry apricots.'}, {'...
# 1  [{'text': 'Combine ingredients in a blender.'}...
# 2  [{'text': 'Toss all ingredients in bowl.'}, {'...
# 3  [{'text': 'Mix butter and flour together well....
# 4  [{'text': 'Preheat oven to 400 degrees F.'}, {...
#
#                                  nutr_per_ingredient  \
# 0  [{'fat': 48.666000000000004, 'nrg': 430.2, 'pr...
# 1  [{'fat': 3.48, 'nrg': 45.0, 'pro': 1.5, 'sat':...
# 2  [{'fat': 2.52, 'nrg': 780.0, 'pro': 3.96, 'sat...
# 3  [{'fat': 2211.84, 'nrg': 19584.0, 'pro': 23.04...
# 4  [{'fat': 0.44, 'nrg': 62.0, 'pro': 3.66, 'sat'...
#
#                                  nutr_values_per100g partition  \
# 0  {'energy': 493.17972350230417, 'fat': 33.46962...      test
# 1  {'energy': 349.68761484748256, 'fat': 27.34962...     train
# 2  {'energy': 292.1303988638368, 'fat': 28.858143...      test
# 3  {'energy': 674.6799974527162, 'fat': 73.404763...     train
# 4  {'energy': 138.38721664808622, 'fat': 10.88814...     train
#
#                                             quantity  \
# 0  [{'text': '60'}, {'text': '1/3'}, {'text': '2'...
# 1  [{'text': '1'}, {'text': '3/4'}, {'text': '1/2...
# 2  [{'text': '12'}, {'text': '13'}, {'text': '14'...
# 3  [{'text': '12'}, {'text': '1'}, {'text': '2'},...
# 4  [{'text': '2'}, {'text': '1/4'}, {'text': '2'}...
#
#                                title  \
# 0         Apricot Florentines Recipe
# 1           Poppyseed Salad Dressing
# 2  Country Style Waldorf Salad for 2
# 3       Patti's Yummy Cheese Nuggets
# 4                  Asian Green Beans
#
#                                                 unit  \
# 0  [{'text': 'g'}, {'text': 'cup'}, {'text': 'tab...
# 1  [{'text': 'tablespoon'}, {'text': 'cup'}, {'te...
# 2  [{'text': 'cup'}, {'text': 'cup'}, {'text': 'c...
# 3  [{'text': 'cup'}, {'text': 'cup'}, {'text': 'c...
# 4  [{'text': 'cup'}, {'text': 'cup'}, {'text': 't...
#
#                                                  url  \
# 0  http://cookeatshare.com/recipes/apricot-floren...
# 1  http://tastykitchen.com/recipes/salads/poppyse...
# 2  http://www.food.com/recipe/country-style-waldo...
# 3  http://www.food.com/recipe/pattis-yummy-cheese...
# 4  http://tastykitchen.com/recipes/sidedishes/asi...
#
#                                      weight_per_ingr
# 0            [60.0, 48.0, 15.625, 71.5, 32.5, 125.0]
# 1  [8.4, 178.8, 100.80000000000001, 2.4, 6.0, 3.7...
# 2  [1500.0, 1313.0, 2114.0, 14.625, 47.0, 3091.20...
# 3           [2726.3999999999996, 125.0, 264.0, 25.2]
# 4                  [200.0, 72.0, 27.0, 19.5, 17.875]

# %%
## read file
flavor_df = pd.read_json(flavor_path);
flavor_df.info()
flavor_df.iloc[:5, :]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   category               934 non-null    object
#  1   entity_id              934 non-null    int64
#  2   category_readable      934 non-null    object
#  3   entity_alias_basket    934 non-null    object
#  4   entity_alias_readable  934 non-null    object
#  5   natural_source_name    934 non-null    object
#  6   entity_alias           934 non-null    object
#  7   molecules              934 non-null    object
#  8   natural_source_url     934 non-null    object
#  9   entity_alias_url       934 non-null    object
#  10  entity_alias_synonyms  934 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 80.4+ KB
#         category  entity_id category_readable  \
# 0  animalproduct          0    Animal Product
# 1         bakery          1            Bakery
# 2         bakery          2            Bakery
# 3         bakery          3            Bakery
# 4         bakery          4            Bakery
#
#                           entity_alias_basket entity_alias_readable  \
# 0  egg, egg-boiled, egg-cooked, egg-scrambled                   Egg
# 1                             bakery-products       Bakery Products
# 2                     bread, bread-preferment                 Bread
# 3                                   bread-rye             Rye Bread
# 4                               bread-wheaten         Wheaten Bread
#
#   natural_source_name   entity_alias  \
# 0             Chicken            egg
# 1            Poacceae         bakery
# 2            Poacceae          bread
# 3                 Rye      bread-rye
# 4               Wheat  bread-wheaten
#
#                                            molecules  \
# 0  [{'bond_stereo_count': 0, 'undefined_atom_ster...
# 1  [{'bond_stereo_count': 0, 'undefined_atom_ster...
# 2  [{'bond_stereo_count': 0, 'undefined_atom_ster...
# 3  [{'bond_stereo_count': 0, 'undefined_atom_ster...
# 4  [{'bond_stereo_count': 0, 'undefined_atom_ster...
#
#                       natural_source_url  \
# 0  https://en.wikipedia.org/wiki/Chicken
# 1  https://en.wikipedia.org/wiki/Poaceae
# 2  https://en.wikipedia.org/wiki/Poaceae
# 3      https://en.wikipedia.org/wiki/Rye
# 4    https://en.wikipedia.org/wiki/Wheat
#
#                             entity_alias_url    entity_alias_synonyms
# 0  https://en.wikipedia.org/wiki/Egg_as_food                      Egg
# 1       https://en.wikipedia.org/wiki/Bakery          Bakery Products
# 2        https://en.wikipedia.org/wiki/Bread                    Bread
# 3    https://en.wikipedia.org/wiki/Rye_bread                Rye Bread
# 4   https://en.wikipedia.org/wiki/Soda_bread  Soda scones, Soda farls

# %%
## flatten molecules from nested array
flatten_flavor_df = flatten(flavor_path, ["molecules"], ["entity_id", "category", "entity_alias_readable"])
flatten_flavor_df.iloc[0:3,:]
# Out:
#    bond_stereo_count  undefined_atom_stereocenter_count  \
# 0                  0                                  0
# 1                  0                                  0
# 2                  0                                  0
#
#                                           taste  \
# 0
# 1  warm, over-ripe, fruity flavor below 0.1 ppm
# 2
#
#                                    functional_groups  \
# 0  amine@primary amine@primary aliphatic amine (a...
# 1            aromatic compound@heterocyclic compound
# 2            aromatic compound@heterocyclic compound
#
#                                fooddb_flavor_profile supersweetdb_id  \
# 0                                              faint
# 1     very strong@mothball@animal@fecal@indole@civet
# 2  roast beef@roasted nuts@grass@medical@cocoa@wo...
#
#   fema_number  fooddb_id           common_name  hba_count  ...  hbd_count  \
# 0        3819  FDB002257            L-arginine          4  ...          4
# 1        3019  FDB010993        3-Methylindole          0  ...          1
# 2        3272  FDB013954  2,5-Dimethylpyrazine          2  ...          0
#
#               fema_flavor_profile complexity  heavy_atom_count  \
# 0                                      176.0                12
# 1                                      122.0                10
# 2  Cocoa, Roast Beef, Roasted Nut       62.9                 8
#
#    defined_atom_stereocenter_count monoisotopic_mass  atom_stereo_count  \
# 0                                1           174.112                  1
# 1                                0           131.073                  0
# 2                                0           108.069                  0
#
#    entity_id       category  entity_alias_readable
# 0          0  animalproduct                    Egg
# 1          0  animalproduct                    Egg
# 2          0  animalproduct                    Egg
#
# [3 rows x 46 columns]

# %%
## flatten ingredients from nested array
partition = 200
flatten_food_df = flatten(food_path, ["ingredients"], ["id", "title"])
# flatten_food_df = flatten_food_df.iloc[0:partition, :] # partition to a small subset for testing

## re-order the column header and rename ingredient
flatten_food_df = flatten_food_df[["id", "title", "text"]]
flatten_food_df = flatten_food_df.rename(columns = {"text": "ingredient"})
flatten_food_df = flatten_food_df.drop_duplicates(subset=['id', 'ingredient']) # remove duplicated ingredients for each food
flatten_food_df = flatten_food_df.reset_index(drop=True)

# %%
flatten_food_df.info()
flatten_food_df.iloc[0:12, :]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5878 entries, 0 to 5877
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          5878 non-null   object
#  1   title       5878 non-null   object
#  2   ingredient  5878 non-null   object
# dtypes: object(3)
# memory usage: 137.9+ KB
#             id                       title  \
# 0   fb51dbcb2f  Apricot Florentines Recipe
# 1   fb51dbcb2f  Apricot Florentines Recipe
# 2   fb51dbcb2f  Apricot Florentines Recipe
# 3   fb51dbcb2f  Apricot Florentines Recipe
# 4   fb51dbcb2f  Apricot Florentines Recipe
# 5   fb51dbcb2f  Apricot Florentines Recipe
# 6   46dbd27b9a    Poppyseed Salad Dressing
# 7   46dbd27b9a    Poppyseed Salad Dressing
# 8   46dbd27b9a    Poppyseed Salad Dressing
# 9   46dbd27b9a    Poppyseed Salad Dressing
# 10  46dbd27b9a    Poppyseed Salad Dressing
# 11  46dbd27b9a    Poppyseed Salad Dressing
#
#                                            ingredient
# 0                                butter, without salt
# 1                                       sugars, brown
# 2         wheat flour, white, all-purpose, unenriched
# 3                                       nuts, almonds
# 4                 apricots, dried, sulfured, uncooked
# 5   spartan, real semi-sweet chocolate baking chip...
# 6                                  spices, poppy seed
# 7                                      vinegar, cider
# 8                                  sugars, granulated
# 9                                spices, onion powder
# 10                                        salt, table
# 11                          mustard, prepared, yellow

# %%
## count number of uninque ingredient for each food
## after deduplicated the ingredients, group them into list
unique_ingredient = flatten_food_df[["id", "ingredient"]].groupby(["id"]).agg(unique_ingredient=("ingredient", lambda x : list(x))).reset_index()
unique_ingredient["ingredient_count"] = unique_ingredient["unique_ingredient"].apply(lambda x : len(x))

# %%
unique_ingredient.info()
unique_ingredient.iloc[:10, :]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1000 non-null   object
#  1   unique_ingredient  1000 non-null   object
#  2   ingredient_count   1000 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 23.6+ KB
#            id                                  unique_ingredient  \
# 0  005e671ac4  [cream, fluid, heavy whipping, sugars, brown, ...
# 1  00703db954  [oats, seeds, sesame seeds, whole, dried, seed...
# 2  007e544c80  [soup, chicken broth or bouillon, dry, onions,...
# 3  00a0ea8691  [rice, white, long-grain, regular, unenriched,...
# 4  00deb3f9f4  [oil, olive, salad or cooking, vinegar, balsam...
# 5  00fb62a5c5  [strawberries, raw, sugars, granulated, spices...
# 6  01680dde21  [wheat flour, white, all-purpose, unenriched, ...
# 7  01e8a5eafa  [cheese, parmesan, hard, candies, marshmallows...
# 8  021fc34777  [cheese, cottage, creamed, large or small curd...
# 9  02ac814cc8  [pork, fresh, loin, country-style ribs, separa...
#
#    ingredient_count
# 0                 5
# 1                 8
# 2                 9
# 3                 9
# 4                 9
# 5                 4
# 6                 9
# 7                 4
# 8                 3
# 9                10

# %%
## flatten, extract the molecule info
flatten_flavor_df = flatten_flavor_df[["category", "entity_alias_readable", "fooddb_id", "pubchem_id", "common_name", "iupac_name", "taste", "odor", "flavor_profile"]]
flatten_flavor_df.iloc[0:10, :]
# Out:
#         category entity_alias_readable  fooddb_id  pubchem_id  \
# 0  animalproduct                   Egg  FDB002257        6322
# 1  animalproduct                   Egg  FDB010993        6736
# 2  animalproduct                   Egg  FDB013954       31252
# 3  animalproduct                   Egg  FDB008174        7909
# 4  animalproduct                   Egg  FDB008127        7284
# 5  animalproduct                   Egg  FDB012552        7501
# 6  animalproduct                   Egg  FDB008326        9609
# 7  animalproduct                   Egg  FDB012084       12180
# 8  animalproduct                   Egg  FDB003349       18827
# 9  animalproduct                   Egg  FDB008541       18635
#
#                      common_name  \
# 0                     L-arginine
# 1                 3-Methylindole
# 2           2,5-Dimethylpyrazine
# 3           4-Methyl-2-pentanone
# 4          2-Methylbutyraldehyde
# 5                        Styrene
# 6                Diethyl sulfide
# 7                Methyl butyrate
# 8                   1-Octen-3-Ol
# 9  3-(Methylthio)propionaldehyde
#
#                                           iupac_name  \
# 0  (2S)-2-amino-5-(diaminomethylideneamino)pentan...
# 1                                 3-methyl-1H-indole
# 2                               2,5-dimethylpyrazine
# 3                               4-methylpentan-2-one
# 4                                    2-methylbutanal
# 5                                            styrene
# 6                                ethylsulfanylethane
# 7                                   methyl butanoate
# 8                                      oct-1-en-3-ol
# 9                           3-methylsulfanylpropanal
#
#                                                taste  \
# 0
# 1       warm, over-ripe, fruity flavor below 0.1 ppm
# 2
# 3
# 4
# 5
# 6
# 7  apple-like, sweet taste@not very powerful@belo...
# 8
# 9
#
#                                                 odor  \
# 0
# 1  characteristic fecal odor at high levels, beco...
# 2
# 3      pleasant odor@faint, ketonic and camphor odor
# 4
# 5  extremely penetrating@an aromatic odor@sweet, ...
# 6                     garlic-like odor@ethereal odor
# 7                                    apple-like odor
# 8
# 9
#
#                                       flavor_profile
# 0                                              faint
# 1     very strong@mothball@animal@fecal@indole@civet
# 2  roast beef@roasted nuts@grass@medical@cocoa@wo...
# 3      solvent@spice@herbal@sharp@fruity@dairy@green
# 4                    musty@coffee@cocoa@nutty@almond
# 5      balsamic@gasoline@floral@sweet@balsam@plastic
# 6                                 ethereal@sulfurous
# 7    apple@pineapple@ether@banana@fruit@sweet@fruity
# 8  raw@fishy@oily@earthy@fungal@chicken@mushroom@...
# 9  potato@vegetable@tomato@fishy@musty@earthy@cre...

# %%
## fuzzywuzzy implementation
ingredients = flavor_df["entity_alias_readable"].unique()
start = time.process_time()
i = 2 ## pick first two key words
flatten_food_df["key"] = flatten_food_df['ingredient'].apply(lambda x : [process.extract(','.join(x.split(',')[:i]), ingredients, limit=1)][0][0][0])
duration = time.process_time() - start 
print(duration)
# Out:
# 266.952291

# %%
# # levenshtein implementation
# ingredients = flatten_flavor_df["entity_alias_readable"].unique()
# start = time.process_time()
# i = 2
# flatten_food_df['key']=flatten_food_df['ingredient'].apply(lambda x : min(ingredients, key=lambda j : lev(','.join(x.split(',')[:i]), j))) 
# duration = time.process_time() - start 
# print(duration)

# %%
flatten_food_df.iloc[0:10, :]
# Out:
#            id                       title  \
# 0  fb51dbcb2f  Apricot Florentines Recipe
# 1  fb51dbcb2f  Apricot Florentines Recipe
# 2  fb51dbcb2f  Apricot Florentines Recipe
# 3  fb51dbcb2f  Apricot Florentines Recipe
# 4  fb51dbcb2f  Apricot Florentines Recipe
# 5  fb51dbcb2f  Apricot Florentines Recipe
# 6  46dbd27b9a    Poppyseed Salad Dressing
# 7  46dbd27b9a    Poppyseed Salad Dressing
# 8  46dbd27b9a    Poppyseed Salad Dressing
# 9  46dbd27b9a    Poppyseed Salad Dressing
#
#                                           ingredient                  key
# 0                               butter, without salt               Butter
# 1                                      sugars, brown                Sugar
# 2        wheat flour, white, all-purpose, unenriched                Wheat
# 3                                      nuts, almonds               Almond
# 4                apricots, dried, sulfured, uncooked              Apricot
# 5  spartan, real semi-sweet chocolate baking chip...            Chocolate
# 6                                 spices, poppy seed           Poppy Seed
# 7                                     vinegar, cider  Apple Cider Vinegar
# 8                                 sugars, granulated                Sugar
# 9                               spices, onion powder                Onion

# %%
## join two dataset on ingredients
merged_df = flatten_flavor_df.merge(flatten_food_df,left_on='entity_alias_readable',right_on='key', how="inner")
merged_df = merged_df.sort_values(by=["id"])
merged_df = merged_df.reset_index(drop=True)
## reorder the cols
merged_df = merged_df[["id", "title", "ingredient", "category", "entity_alias_readable", "fooddb_id", "pubchem_id", "common_name", "iupac_name", "taste", "odor", "flavor_profile"]]
merged_df = merged_df.rename(columns = {"title": "food", "entity_alias_readable": "ingredient_flavorDB"})

# %%
## flatten col "nutrition per 100g"
## then join
# with open(food_path,'r') as f:
#     data = json.loads(f.read())
# nutr = pd.json_normalize(data)
# flatten_nutr = nutr.filter(regex="nutr_values_per100g")
# flatten_nutr.insert(0, "title", nutr["title"], True)
# flatten_nutr.insert(0, "id", nutr["id"], True)

# %%
merged_df.info()
merged_df.iloc[0:10, :]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584128 entries, 0 to 584127
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   584128 non-null  object
#  1   food                 584128 non-null  object
#  2   ingredient           584128 non-null  object
#  3   category             584128 non-null  object
#  4   ingredient_flavorDB  584128 non-null  object
#  5   fooddb_id            584128 non-null  object
#  6   pubchem_id           584128 non-null  int64
#  7   common_name          584128 non-null  object
#  8   iupac_name           584128 non-null  object
#  9   taste                584128 non-null  object
#  10  odor                 584128 non-null  object
#  11  flavor_profile       584128 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 53.5+ MB
#            id            food            ingredient       category  \
# 0  005e671ac4  Pecan Pralines       vanilla extract  fruit-essence
# 1  005e671ac4  Pecan Pralines       vanilla extract  fruit-essence
# 2  005e671ac4  Pecan Pralines  butter, without salt          dairy
# 3  005e671ac4  Pecan Pralines       vanilla extract  fruit-essence
# 4  005e671ac4  Pecan Pralines  butter, without salt          dairy
# 5  005e671ac4  Pecan Pralines       vanilla extract  fruit-essence
# 6  005e671ac4  Pecan Pralines       vanilla extract  fruit-essence
# 7  005e671ac4  Pecan Pralines       vanilla extract  fruit-essence
# 8  005e671ac4  Pecan Pralines  butter, without salt          dairy
# 9  005e671ac4  Pecan Pralines       vanilla extract  fruit-essence
#
#   ingredient_flavorDB  fooddb_id  pubchem_id          common_name  \
# 0             Vanilla  FDB009020         247              betaine
# 1             Vanilla  FDB003285       11552      3-Methylbutanal
# 2              Butter  FDB012552        7501              Styrene
# 3             Vanilla  FDB020874        9895     beta-Cyclocitral
# 4              Butter  FDB001224      644104           CID 644104
# 5             Vanilla  FDB012090        7519              Anisole
# 6             Vanilla  FDB008173       11508  3-Methyl-1-Pentanol
# 7             Vanilla  FDB000881       13144      calcium lactate
# 8              Butter  FDB012084       12180      Methyl butyrate
# 9             Vanilla  FDB013794     1549026      Geranyl Acetate
#
#                                           iupac_name  \
# 0                      2-(trimethylazaniumyl)acetate
# 1                                    3-methylbutanal
# 2                                            styrene
# 3          2,6,6-trimethylcyclohexene-1-carbaldehyde
# 4  (2S)-2-[(1R)-1,2-dihydroxyethyl]-4,5-dihydroxy...
# 5                                            anisole
# 6                                3-methylpentan-1-ol
# 7                        calcium;2-hydroxypropanoate
# 8                                   methyl butanoate
# 9         [(2E)-3,7-dimethylocta-2,6-dienyl] acetate
#
#                                                taste  \
# 0                                              sweet
# 1  at very low levels the flavor is warm, herbace...
# 2
# 3
# 4
# 5                                              sweet
# 6
# 7
# 8  apple-like, sweet taste@not very powerful@belo...
# 9  taste threshold values: taste characteristics ...
#
#                                                 odor  \
# 0
# 1   apple-like odor@powerful penetrating, acrid odor
# 2  extremely penetrating@an aromatic odor@sweet, ...
# 3
# 4
# 5  sweet anise-like odor@agreeable aromatic odor@...
# 6
# 7
# 8                                    apple-like odor
# 9  odor of lavender@sweet, fruity-floral, rosy, s...
#
#                                       flavor_profile
# 0                                              bland
# 1  peach@sour@chocolate@ethereal@malt@fatty@aldeh...
# 2      balsamic@gasoline@floral@sweet@balsam@plastic
# 3  mint@saffron@tobacco@herbal@damascone@sweet@tr...
# 4                                   grassy@very mild
# 5  butter@ethereal@alcohol@gasoline@anise@cheese@...
# 6               wine@fusel@cocoa@fruity@cognac@green
# 7                                           odorless
# 8    apple@pineapple@ether@banana@fruit@sweet@fruity
# 9             waxy@rose@lavender@green@floral@bitter

# %%
## count the freq of category of ingredients for each food
category_freq = merged_df[["id", "food", "ingredient", "category"]].drop_duplicates(subset=["id", "ingredient"]).groupby(['id', 'food','category'],  as_index=False)['id'].agg({'Frequency':'count'})

# %%
category_freq.info()
category_freq.iloc[:10, :]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4389 entries, 0 to 4388
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         4389 non-null   object
#  1   food       4389 non-null   object
#  2   category   4389 non-null   object
#  3   Frequency  4389 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 137.3+ KB
#            id              food           category  Frequency
# 0  005e671ac4    Pecan Pralines           additive          1
# 1  005e671ac4    Pecan Pralines              dairy          2
# 2  005e671ac4    Pecan Pralines      fruit-essence          1
# 3  005e671ac4    Pecan Pralines        nutseed-nut          1
# 4  00703db954  Greatest Granola           additive          1
# 5  00703db954  Greatest Granola  cerealcrop-cereal          1
# 6  00703db954  Greatest Granola             flower          1
# 7  00703db954  Greatest Granola              fruit          1
# 8  00703db954  Greatest Granola       nutseed-seed          1
# 9  00703db954  Greatest Granola              plant          1

# %%
## group the category freq into {key, val} pairs
category_freq["count"] = category_freq.apply(lambda x : {x["category"]: x["Frequency"]}, axis=1)
category_freq = category_freq.groupby(["id"], as_index=False).agg(category_freq=("count", lambda x : list(x)))

# %%
category_freq.iloc[:5, :]
# Out:
#            id                                      category_freq
# 0  005e671ac4  [{'additive': 1}, {'dairy': 2}, {'fruit-essenc...
# 1  00703db954  [{'additive': 1}, {'cerealcrop-cereal': 1}, {'...
# 2  007e544c80  [{'additive': 1}, {'cerealcrop-cereal': 1}, {'...
# 3  00a0ea8691  [{'additive': 1}, {'cerealcrop-cereal': 1}, {'...
# 4  00deb3f9f4  [{'additive': 1}, {'fruit-berry': 1}, {'nutsee...

# %%
## make set of molecules for each food
unique_molecules = merged_df[["id", "food", "ingredient_flavorDB", "fooddb_id", "pubchem_id", "common_name", "taste", "odor", "flavor_profile"]]
unique_molecules = unique_molecules.drop_duplicates(subset=["id", "pubchem_id"])

# %%
display(unique_molecules.iloc[:10, :])
unique_molecules.info()
# Out:
#            id            food ingredient_flavorDB  fooddb_id  pubchem_id  \
# 0  005e671ac4  Pecan Pralines             Vanilla  FDB009020         247
# 1  005e671ac4  Pecan Pralines             Vanilla  FDB003285       11552
# 2  005e671ac4  Pecan Pralines              Butter  FDB012552        7501
# 3  005e671ac4  Pecan Pralines             Vanilla  FDB020874        9895
# 4  005e671ac4  Pecan Pralines              Butter  FDB001224      644104
# 5  005e671ac4  Pecan Pralines             Vanilla  FDB012090        7519
# 6  005e671ac4  Pecan Pralines             Vanilla  FDB008173       11508
# 7  005e671ac4  Pecan Pralines             Vanilla  FDB000881       13144
# 8  005e671ac4  Pecan Pralines              Butter  FDB012084       12180
# 9  005e671ac4  Pecan Pralines             Vanilla  FDB013794     1549026
#
#            common_name                                              taste  \
# 0              betaine                                              sweet
# 1      3-Methylbutanal  at very low levels the flavor is warm, herbace...
# 2              Styrene
# 3     beta-Cyclocitral
# 4           CID 644104
# 5              Anisole                                              sweet
# 6  3-Methyl-1-Pentanol
# 7      calcium lactate
# 8      Methyl butyrate  apple-like, sweet taste@not very powerful@belo...
# 9      Geranyl Acetate  taste threshold values: taste characteristics ...
#
#                                                 odor  \
# 0
# 1   apple-like odor@powerful penetrating, acrid odor
# 2  extremely penetrating@an aromatic odor@sweet, ...
# 3
# 4
# 5  sweet anise-like odor@agreeable aromatic odor@...
# 6
# 7
# 8                                    apple-like odor
# 9  odor of lavender@sweet, fruity-floral, rosy, s...
#
#                                       flavor_profile
# 0                                              bland
# 1  peach@sour@chocolate@ethereal@malt@fatty@aldeh...
# 2      balsamic@gasoline@floral@sweet@balsam@plastic
# 3  mint@saffron@tobacco@herbal@damascone@sweet@tr...
# 4                                   grassy@very mild
# 5  butter@ethereal@alcohol@gasoline@anise@cheese@...
# 6               wine@fusel@cocoa@fruity@cognac@green
# 7                                           odorless
# 8    apple@pineapple@ether@banana@fruit@sweet@fruity
# 9             waxy@rose@lavender@green@floral@bitter
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 311515 entries, 0 to 584127
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   311515 non-null  object
#  1   food                 311515 non-null  object
#  2   ingredient_flavorDB  311515 non-null  object
#  3   fooddb_id            311515 non-null  object
#  4   pubchem_id           311515 non-null  int64
#  5   common_name          311515 non-null  object
#  6   taste                311515 non-null  object
#  7   odor                 311515 non-null  object
#  8   flavor_profile       311515 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 23.8+ MB

# %%
## make molecule attributes into {key: val} pair
columns = ["ingredient_flavorDB", "fooddb_id", "pubchem_id", "common_name", "taste", "odor", "flavor_profile"]
unique_molecules["molecules"] = unique_molecules[columns].to_dict(orient="records")

## group by each food
unique_molecules = unique_molecules[["id", "food", "molecules"]]
unique_molecules = unique_molecules.groupby(["id", "food"], as_index=False).agg(flavor_molecules=("molecules", lambda x : list(x)))

# %%
display(unique_molecules)
# Out:
#              id                               food  \
# 0    005e671ac4                     Pecan Pralines
# 1    00703db954                   Greatest Granola
# 2    007e544c80    Cream of Fresh Cauliflower Soup
# 3    00a0ea8691              Sausage and Rice Bake
# 4    00deb3f9f4  Spicy Raspberry Balsamic Dressing
# ..          ...                                ...
# 995  ff3633834a                Pumpkin Pie Oatmeal
# 996  ff89c7f54c         Pizza Dough Focaccia (Abm)
# 997  ffb3c891c2                     Cardinal Punch
# 998  ffde39a0da        Five Minute Berry Ice Cream
# 999  fff2c7c05d              Zesty Mashed Potatoes
#
#                                       flavor_molecules
# 0    [{'ingredient_flavorDB': 'Vanilla', 'fooddb_id...
# 1    [{'ingredient_flavorDB': 'Sesame', 'fooddb_id'...
# 2    [{'ingredient_flavorDB': 'Milk', 'fooddb_id': ...
# 3    [{'ingredient_flavorDB': 'Rice', 'fooddb_id': ...
# 4    [{'ingredient_flavorDB': 'Raspberry', 'fooddb_...
# ..                                                 ...
# 995  [{'ingredient_flavorDB': 'Pumpkin', 'fooddb_id...
# 996  [{'ingredient_flavorDB': 'Olive', 'fooddb_id':...
# 997  [{'ingredient_flavorDB': 'Lemon', 'fooddb_id':...
# 998  [{'ingredient_flavorDB': 'Vanilla', 'fooddb_id...
# 999  [{'ingredient_flavorDB': 'Potato', 'fooddb_id'...
#
# [1000 rows x 3 columns]

# %%
## count number of distinct flavor_molecules for each food
unique_molecules["molecules_count"] = unique_molecules.apply(lambda x : len(x['flavor_molecules']), axis=1)

# %%
display(unique_molecules.iloc[0:5, :])
unique_molecules.info()
# Out:
#            id                               food  \
# 0  005e671ac4                     Pecan Pralines
# 1  00703db954                   Greatest Granola
# 2  007e544c80    Cream of Fresh Cauliflower Soup
# 3  00a0ea8691              Sausage and Rice Bake
# 4  00deb3f9f4  Spicy Raspberry Balsamic Dressing
#
#                                     flavor_molecules  molecules_count
# 0  [{'ingredient_flavorDB': 'Vanilla', 'fooddb_id...              261
# 1  [{'ingredient_flavorDB': 'Sesame', 'fooddb_id'...              306
# 2  [{'ingredient_flavorDB': 'Milk', 'fooddb_id': ...              506
# 3  [{'ingredient_flavorDB': 'Rice', 'fooddb_id': ...              470
# 4  [{'ingredient_flavorDB': 'Raspberry', 'fooddb_...              462
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1000 non-null   object
#  1   food              1000 non-null   object
#  2   flavor_molecules  1000 non-null   object
#  3   molecules_count   1000 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 31.4+ KB

# %%
# add attributes: fsa_lights_per100g, ingredients, nutr_values_per100g
final_df = unique_molecules.merge(food_df[["id","instructions", "nutr_values_per100g", "fsa_lights_per100g"]], on="id", how="inner")

## add unique ingredients for each food
final_df = final_df.merge(unique_ingredient, on="id", how="left")
# add category freq
final_df = final_df.merge(category_freq, on="id", how="left")

# reorder column
final_df = final_df[["id", "food",  "unique_ingredient",  "ingredient_count", "category_freq", "instructions", "nutr_values_per100g", "fsa_lights_per100g", "flavor_molecules", "molecules_count"]]

# %%
final_df.info()
display(final_df.iloc[:10, :])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1000 non-null   object
#  1   food                 1000 non-null   object
#  2   unique_ingredient    1000 non-null   object
#  3   ingredient_count     1000 non-null   int64
#  4   category_freq        1000 non-null   object
#  5   instructions         1000 non-null   object
#  6   nutr_values_per100g  1000 non-null   object
#  7   fsa_lights_per100g   1000 non-null   object
#  8   flavor_molecules     1000 non-null   object
#  9   molecules_count      1000 non-null   int64
# dtypes: int64(2), object(8)
# memory usage: 85.9+ KB
#            id                                    food  \
# 0  005e671ac4                          Pecan Pralines
# 1  00703db954                        Greatest Granola
# 2  007e544c80         Cream of Fresh Cauliflower Soup
# 3  00a0ea8691                   Sausage and Rice Bake
# 4  00deb3f9f4       Spicy Raspberry Balsamic Dressing
# 5  00fb62a5c5  Roasted Strawberries with Black Pepper
# 6  01680dde21             Easy Cheese and Onion Bread
# 7  01e8a5eafa            Orange Marshmallow Fruit Dip
# 8  021fc34777        Cherry Tomatoes (Stuffed) Recipe
# 9  02ac814cc8                          BBQ Short Ribs
#
#                                    unique_ingredient  ingredient_count  \
# 0  [cream, fluid, heavy whipping, sugars, brown, ...                 5
# 1  [oats, seeds, sesame seeds, whole, dried, seed...                 8
# 2  [soup, chicken broth or bouillon, dry, onions,...                 9
# 3  [rice, white, long-grain, regular, unenriched,...                 9
# 4  [oil, olive, salad or cooking, vinegar, balsam...                 9
# 5  [strawberries, raw, sugars, granulated, spices...                 4
# 6  [wheat flour, white, all-purpose, unenriched, ...                 9
# 7  [cheese, parmesan, hard, candies, marshmallows...                 4
# 8  [cheese, cottage, creamed, large or small curd...                 3
# 9  [pork, fresh, loin, country-style ribs, separa...                10
#
#                                        category_freq  \
# 0  [{'additive': 1}, {'dairy': 2}, {'fruit-essenc...
# 1  [{'additive': 1}, {'cerealcrop-cereal': 1}, {'...
# 2  [{'additive': 1}, {'cerealcrop-cereal': 1}, {'...
# 3  [{'additive': 1}, {'cerealcrop-cereal': 1}, {'...
# 4  [{'additive': 1}, {'fruit-berry': 1}, {'nutsee...
# 5  [{'additive': 1}, {'fruit-berry': 1}, {'plantd...
# 6  [{'additive': 4}, {'cerealcrop-cereal': 1}, {'...
# 7  [{'bakery': 1}, {'beverage-alcoholic': 1}, {'d...
# 8      [{'dairy': 1}, {'herb': 1}, {'vegetable': 1}]
# 9  [{'additive': 3}, {'cerealcrop-cereal': 1}, {'...
#
#                                         instructions  \
# 0  [{'text': 'Butter a medium saucepan--this will...
# 1  [{'text': 'Preheat oven to 300F.'}, {'text': '...
# 2  [{'text': 'In a saucepan, combine the chicken ...
# 3  [{'text': 'In a shallow 2 qt casserole, place ...
# 4  [{'text': 'Whisk olive oil, balsamic vinegar, ...
# 5  [{'text': 'Rinse the strawberries in cool wate...
# 6  [{'text': 'Pre-heat oven to 375 degrees.'}, {'...
# 7  [{'text': 'Blend all ingredients until smooth....
# 8  [{'text': 'Scoop inside out of tomatoes with a...
# 9  [{'text': 'Trim excess fat from ribs.'}, {'tex...
#
#                                  nutr_values_per100g  \
# 0  {'energy': 435.96474779673724, 'fat': 24.98968...
# 1  {'energy': 580.1557272750255, 'fat': 48.485788...
# 2  {'energy': 67.29209889741522, 'fat': 2.1389872...
# 3  {'energy': 123.63363927171838, 'fat': 10.13025...
# 4  {'energy': 569.6636925188744, 'fat': 60.804891...
# 5  {'energy': 56.37505476851177, 'fat': 0.2994011...
# 6  {'energy': 313.06332866624007, 'fat': 22.63932...
# 7  {'energy': 336.24522884980854, 'fat': 12.93647...
# 8  {'energy': 96.25225259952394, 'fat': 4.1964363...
# 9  {'energy': 73.60967983814265, 'fat': 2.2422616...
#
#                                   fsa_lights_per100g  \
# 0  {'fat': 'red', 'salt': 'green', 'saturates': '...
# 1  {'fat': 'red', 'salt': 'green', 'saturates': '...
# 2  {'fat': 'green', 'salt': 'red', 'saturates': '...
# 3  {'fat': 'orange', 'salt': 'red', 'saturates': ...
# 4  {'fat': 'red', 'salt': 'orange', 'saturates': ...
# 5  {'fat': 'green', 'salt': 'green', 'saturates':...
# 6  {'fat': 'red', 'salt': 'green', 'saturates': '...
# 7  {'fat': 'orange', 'salt': 'red', 'saturates': ...
# 8  {'fat': 'orange', 'salt': 'orange', 'saturates...
# 9  {'fat': 'green', 'salt': 'green', 'saturates':...
#
#                                     flavor_molecules  molecules_count
# 0  [{'ingredient_flavorDB': 'Vanilla', 'fooddb_id...              261
# 1  [{'ingredient_flavorDB': 'Sesame', 'fooddb_id'...              306
# 2  [{'ingredient_flavorDB': 'Milk', 'fooddb_id': ...              506
# 3  [{'ingredient_flavorDB': 'Rice', 'fooddb_id': ...              470
# 4  [{'ingredient_flavorDB': 'Raspberry', 'fooddb_...              462
# 5  [{'ingredient_flavorDB': 'Strawberry', 'fooddb...              382
# 6  [{'ingredient_flavorDB': 'Milk', 'fooddb_id': ...              372
# 7  [{'ingredient_flavorDB': 'Parmesan Cheese', 'f...              357
# 8  [{'ingredient_flavorDB': 'Dill', 'fooddb_id': ...              306
# 9  [{'ingredient_flavorDB': 'Pork', 'fooddb_id': ...              550

# %%
## verify the freq of ingredient category, sum of freq should be equal to number of ingredients
final_df['category_freq'].apply(lambda x : sum(list(e.values())[0] for e in x))
final_df[final_df["ingredient_count"] != final_df['category_freq'].apply(lambda x : sum(list(e.values())[0] for e in x))].shape[0]
# Out:
# 0

# %%
## small portion to view
final_df.iloc[:10, :].to_json(r'ugly_schema.json', orient="records")
# !cat ugly.json | python -mjson.tool > schema.json
print("writing finished")
# Out:
# writing finished

# %%
## small portion to view
final_df.to_json(r'joined_dev_set.json', orient="records")
print("writing finished")
# Out:
# writing finished

# %%
# !cat joined_dev_set.json | python -mjson.tool > pretty_joined_dev_set.json
